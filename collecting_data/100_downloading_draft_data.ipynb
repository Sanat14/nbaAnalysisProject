# %% [markdown]
# # Retrieving Draft Data

# %% [markdown]
# We will be using the `nba_api` which is an inbuilt library in python that allows us to scrape different categories of data (depending on the endpoint) directly from the official nba site (https://www.nba.com/stats).
#
# Drafts are when players fresh out of college are picked by teams to play in the NBA. In this notebook we'll scrape 2 different datasets : past drafts and information about players (such as height, weight etc). We will use the `drafthistory` and `draftcombinestats` endpoints included in the `nba_api` to do this. We will then merge these two datasets (when cleaning this data) which will enable us to analyse one of our research questions a lot better

# %%
import pandas as pd
from nba_api.stats.endpoints import drafthistory
from nba_api.stats.endpoints import draftcombinestats
import matplotlib.pyplot as plt
import os

# %% [markdown]
# Collecting draft data :

# %%
draft_data = drafthistory.DraftHistory()

# %%
draft_df = draft_data.get_data_frames()[0]
draft_df
# Out:
#       PERSON_ID        PLAYER_NAME SEASON  ROUND_NUMBER  ROUND_PICK  \
# 0       1641705  Victor Wembanyama   2023             1           1
# 1       1641706     Brandon Miller   2023             1           2
# 2       1630703    Scoot Henderson   2023             1           3
# 3       1641708      Amen Thompson   2023             1           4
# 4       1641709     Ausar Thompson   2023             1           5
# ...         ...                ...    ...           ...         ...
# 8252      79312     Herb Wilkinson   1947             0           0
# 8253      79284         Jack Stone   1947             0           0
# 8254      79313      Frank Broyles   1947             0           0
# 8255      79283        Hank Decker   1947             0           0
# 8256      76773     Harry Gallatin   1947             0           0
#
#       OVERALL_PICK DRAFT_TYPE     TEAM_ID    TEAM_CITY      TEAM_NAME  \
# 0                1      Draft  1610612759  San Antonio          Spurs
# 1                2      Draft  1610612766    Charlotte        Hornets
# 2                3      Draft  1610612757     Portland  Trail Blazers
# 3                4      Draft  1610612745      Houston        Rockets
# 4                5      Draft  1610612765      Detroit        Pistons
# ...            ...        ...         ...          ...            ...
# 8252             0      Draft  1610610034    St. Louis        Bombers
# 8253             0      Draft  1610610025      Chicago          Stags
# 8254             0      Draft  1610610035      Toronto        Huskies
# 8255             0      Draft  1610610025      Chicago          Stags
# 8256             0      Draft  1610610024    Baltimore        Bullets
#
#      TEAM_ABBREVIATION               ORGANIZATION   ORGANIZATION_TYPE  \
# 0                  SAS  Metropolitans 92 (France)     Other Team/Club
# 1                  CHA                    Alabama  College/University
# 2                  POR          Ignite (G League)     Other Team/Club
# 3                  HOU             Overtime Elite     Other Team/Club
# 4                  DET             Overtime Elite     Other Team/Club
# ...                ...                        ...                 ...
# 8252               BOM                       Iowa  College/University
# 8253               CHS               Kansas State  College/University
# 8254               HUS               Georgia Tech  College/University
# 8255               CHS             West Texas A&M  College/University
# 8256               BAL               Truman State  College/University
#
#       PLAYER_PROFILE_FLAG
# 0                       1
# 1                       1
# 2                       1
# 3                       1
# 4                       1
# ...                   ...
# 8252                    0
# 8253                    0
# 8254                    0
# 8255                    0
# 8256                    1
#
# [8257 rows x 14 columns]

# %%
draft_df.columns
# Out:
# Index(['PERSON_ID', 'PLAYER_NAME', 'SEASON', 'ROUND_NUMBER', 'ROUND_PICK',
#        'OVERALL_PICK', 'DRAFT_TYPE', 'TEAM_ID', 'TEAM_CITY', 'TEAM_NAME',
#        'TEAM_ABBREVIATION', 'ORGANIZATION', 'ORGANIZATION_TYPE',
#        'PLAYER_PROFILE_FLAG'],
#       dtype='object')

# %% [markdown]
# As we can see we have data on past drafts which goes all the way back to 1947. Now, we likely wont use all this data and will only include drafts from 1990 onwards (refer to `clean_draft_data` notebook)

# %% [markdown]
# Lets save this data to a csv file :

# %%
output_dir = os.path.join("..", "data", "raw", "draft_data")
os.makedirs(output_dir, exist_ok=True)
output_filename = os.path.join(output_dir, "draft_data.csv")
draft_df.to_csv(output_filename, index=False)

# %% [markdown]
# ## Collecting more detailed information about every player :

# %%
player_additional_info = draftcombinestats.DraftCombineStats(season_all_time= 'All Time')
player_additional_info_df= player_additional_info.get_data_frames()[0]

# %%
player_additional_info_df
# Out:
#      SEASON  PLAYER_ID FIRST_NAME  LAST_NAME        PLAYER_NAME POSITION  \
# 0      2002       2403       Nene                         Nene        PF
# 1      2021    1630546        Max      Abmas          Max Abmas       PG
# 2      2007      12204    Mohamed     Abukar     Mohamed Abukar       SF
# 3      2020    1630173   Precious    Achiuwa   Precious Achiuwa       PF
# 4      2005     101165       Alex      Acker         Alex Acker       SG
# ...     ...        ...        ...        ...                ...      ...
# 1628   2012     203092      Tyler     Zeller       Tyler Zeller     PF-C
# 1629   2013     203469       Cody     Zeller        Cody Zeller     C-PF
# 1630   2022    1630855      Fanbo       Zeng         Fanbo Zeng    SF-PF
# 1631   2016    1627757    Stephen  Zimmerman  Stephen Zimmerman        C
# 1632   2003       2583    Derrick  Zimmerman  Derrick Zimmerman       PG
#
#       HEIGHT_WO_SHOES HEIGHT_WO_SHOES_FT_IN  HEIGHT_W_SHOES  \
# 0               81.25             6' 9.25''             NaN
# 1               70.50              5'10.5''           71.75
# 2               80.00                6' 8''           81.75
# 3               79.50              6'7.50''           80.70
# 4               75.75             6' 3.75''           76.75
# ...               ...                   ...             ...
# 1628            83.25            6' 11.25''           84.50
# 1629            82.75            6' 10.75''           84.25
# 1630              NaN                  None             NaN
# 1631            82.25            6' 10.25''           83.75
# 1632            73.00                6' 1''             NaN
#
#      HEIGHT_W_SHOES_FT_IN  ... STANDING_REACH_FT_IN  BODY_FAT_PCT HAND_LENGTH  \
# 0                    None  ...               9' 1''           NaN         NaN
# 1               5'11.75''  ...             7'10.0''          5.50         8.0
# 2               6' 9.75''  ...               8' 7''          8.90         NaN
# 3                6'8.75''  ...             9'0.50''          6.70         9.0
# 4               6' 4.75''  ...             8' 6.5''           NaN         NaN
# ...                   ...  ...                  ...           ...         ...
# 1628             7' 0.5''  ...             8' 8.5''          6.40         9.0
# 1629            7' 0.25''  ...              8' 10''          4.75         8.5
# 1630                 None  ...                 None           NaN         NaN
# 1631           6' 11.75''  ...             9' 0.5''         11.15         9.0
# 1632                 None  ...             8' .25''          5.30         NaN
#
#       HAND_WIDTH STANDING_VERTICAL_LEAP  MAX_VERTICAL_LEAP  LANE_AGILITY_TIME  \
# 0            NaN                   30.0               34.0              10.73
# 1           7.75                   28.5               32.5              10.90
# 2            NaN                   30.5               35.0              11.78
# 3          10.00                    NaN                NaN                NaN
# 4            NaN                   28.0               32.0              11.67
# ...          ...                    ...                ...                ...
# 1628        9.75                   30.0               34.0              11.13
# 1629       10.50                   35.5               37.5              10.82
# 1630         NaN                    NaN                NaN                NaN
# 1631        9.00                   26.0               31.0              12.08
# 1632         NaN                   34.0               40.5              11.09
#
#       MODIFIED_LANE_AGILITY_TIME  THREE_QUARTER_SPRINT  BENCH_PRESS
# 0                            NaN                  3.19         16.0
# 1                           3.49                  3.12          NaN
# 2                            NaN                  3.37         15.0
# 3                            NaN                   NaN          NaN
# 4                            NaN                  3.35         11.0
# ...                          ...                   ...          ...
# 1628                         NaN                  3.40         16.0
# 1629                        2.69                  3.15         17.0
# 1630                         NaN                   NaN          NaN
# 1631                        3.16                  3.43          NaN
# 1632                         NaN                  3.10         13.0
#
# [1633 rows x 24 columns]

# %%
player_additional_info_df.columns
# Out:
# Index(['SEASON', 'PLAYER_ID', 'FIRST_NAME', 'LAST_NAME', 'PLAYER_NAME',
#        'POSITION', 'HEIGHT_WO_SHOES', 'HEIGHT_WO_SHOES_FT_IN',
#        'HEIGHT_W_SHOES', 'HEIGHT_W_SHOES_FT_IN', 'WEIGHT', 'WINGSPAN',
#        'WINGSPAN_FT_IN', 'STANDING_REACH', 'STANDING_REACH_FT_IN',
#        'BODY_FAT_PCT', 'HAND_LENGTH', 'HAND_WIDTH', 'STANDING_VERTICAL_LEAP',
#        'MAX_VERTICAL_LEAP', 'LANE_AGILITY_TIME', 'MODIFIED_LANE_AGILITY_TIME',
#        'THREE_QUARTER_SPRINT', 'BENCH_PRESS'],
#       dtype='object')

# %%
# saving data

output_dir = os.path.join("..", "data", "raw", "player_extra_info")
os.makedirs(output_dir, exist_ok=True)
output_filename = os.path.join(output_dir, "player_moreinfo.csv")
player_additional_info_df.to_csv(output_filename, index=False)
